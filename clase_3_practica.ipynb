# %% [markdown]
# # Parámetros de la función

# %% [markdown]
# ### Parámetros Posicionales: Crear una función llamada multiplicar que reciba dos números y devuelva su producto. Probar la función con diferentes pares de números.

# %%
def multiplicar(num1:int, num2:int) -> int:
    return num1 * num2

print(multiplicar(1, 5))
# Out:
# 5

# %% [markdown]
# ### Parámetros por Defecto: Crear una función llamada bienvenida que reciba un nombre y un mensaje de bienvenida. El mensaje debe tener un valor por defecto de "¡Bienvenido!". Si no se proporciona un mensaje, la función debe usar el valor por defecto. Probar la función proporcionando solo el nombre y con el mensaje.

# %%
def bienvenida(nombre: str, bienvenida= "¡Bienvenido!") -> str:
    return f'Hola {nombre}, {bienvenida}'

print(bienvenida('Moises'))
print(bienvenida('Moises', 'Relax&Enjoy'))
# Out:
# Hola Moises, ¡Bienvenido!
# Hola Moises, Relax&Enjoy

# %% [markdown]
# ### Parámetros Indefinidos (*args): Crear una función llamada calcular_promedio que acepte un número variable de notas (posicionales) y devuelva el promedio de esas notas. Probar la función con diferentes cantidades de notas.

# %%
def calcular_promedio(*args: float) -> str:
    # print(type(args))
    return f'El promedio de las notas es {sum(args)/len(args)}'

print(calcular_promedio(7,8,9))
# Out:
# El promedio de las notas es 8.0

# %% [markdown]
# ### Parámetros de Palabras Clave Indefinidas (**kwargs): Crear una función llamada concatena_info que reciba un nombre y un número indefinido de palabras clave (por ejemplo, edad, ciudad, ocupación) y devuelva un string que combine todos los datos. Probar la función pasando varios pares de clave-valor.

# %%
def concatena_info(nombre: str, **kwargs) -> str:
    return f'El usuario se llama {nombre}, tiene {kwargs.get('edad', 'desconocido')} años, vive en {kwargs.get('ciudad', 'desconocido')} y trabaja como {kwargs.get('ocupación', 'desconocido')}.'

print(concatena_info('Bob', edad= 45, ciudad='TrenchTown', ocupación= "Reggae Singer"))
print(concatena_info('Diego', ciudad='Villa Fiorito', ocupación= "D10S"))
# Out:
# El usuario se llama Bob, tiene 45 años, vive en TrenchTown y trabaja como Reggae Singer.
# El usuario se llama Diego, tiene desconocido años, vive en Villa Fiorito y trabaja como D10S.

# %% [markdown]
# ### Cargar un csv en Google Colab y visualizar sus primeras filas usando Pandas.

# %%
import pandas as pd
import openpyxl

# %% [markdown]
# ### Carga de .csv

# %%
df = pd.read_csv(r"ventas - ventas.csv", sep = ',')
df.head(2)
df.sample(3, random_state= 42)
# Out:
#           Fecha     Vendedor Sede Entrega    Producto      Importe
# 199  30/12/2020  Vendedor 10       Sede A  Producto W   $78,771.17
# 422  24/04/2021   Vendedor 7       Sede A  Producto V  $342,045.09
# 695  26/12/2020   Vendedor 3       Sede D  Producto S   $27,000.44

# %% [markdown]
# ### Carga de .xlsx

# %%
df_xlsx = pd.read_excel(r'ventas.xlsx')
df_xlsx.sample(3, random_state=42)
# Out:
#          Fecha     Vendedor Sede Entrega    Producto     Importe
# 199 2020-12-30  Vendedor 10       Sede A  Producto W   $78771.17
# 422 2021-04-24   Vendedor 7       Sede A  Producto V  $342045.09
# 695 2020-12-26   Vendedor 3       Sede D  Producto S   $27000.44
