# %%
tupla = (1, 2, 3)
print(tupla)
# print(type(tupla))
# print(hex(id(tupla)))
# Out:
# (1, 2, 3)

# %%
tupla = tupla + (4,)
print(tupla)
# print(type(tupla))
# print(hex(id(tupla)))
# Out:
# (1, 2, 3, 4)

# %%
lista = [1, 2]

print(type(lista))
print(hex(id(lista)))
# Out:
# <class 'list'>
# 0x17c33436ec0

# %%
lista.extend([3, 4, 5])  # Resultado: [1, 2, 3, 4, 5]
print(hex(id(lista)))
# Out:
# 0x17c33436ec0
